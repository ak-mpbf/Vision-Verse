# %% [markdown]
# <a href="https://colab.research.google.com/github/ak-mpbf/Vision-Verse/blob/main/Edge_Detection.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import cv2
import numpy as np
from google.colab.patches import cv2_imshow

# %%
images=['1.jpg','2.jpg','3.jpg','4.jpg']

# %% [markdown]
# **CANNY EDGE DETECTION :-**

# %%
for i in range(4):
  # Read the original image
  img = cv2.imread(images[i])
  # Convert to graycsale
  img_gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
  # Blur the image for better edge detection
  img_blur = cv2.GaussianBlur(img_gray, (3,3), 0)
  # Canny Edge Detection
  edges = cv2.Canny(image=img_blur, threshold1=20, threshold2=80)
  print("Image",i+1)
  cv2_imshow(edges)
# Out:
# Image 1
# <PIL.Image.Image image mode=L size=360x250>
# Image 2
# <PIL.Image.Image image mode=L size=200x300>
# Image 3
# <PIL.Image.Image image mode=L size=642x481>
# Image 4
# <PIL.Image.Image image mode=L size=639x479>

# %% [markdown]
# **HOUGH TRANSFORM :-**

# %%
for i in range(4):
  # Read the original image
  img = cv2.imread(images[i])
  # Convert to graycsale
  img_gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
  # Blur the image for better edge detection
  img_blur = cv2.GaussianBlur(img_gray, (3,3), 0)
  # Canny Edge Detection
  edges = cv2.Canny(image=img_blur, threshold1=20, threshold2=80)
  lines = cv2.HoughLinesP(edges, 1, np.pi/180, threshold=1, minLineLength=1, maxLineGap=5)
  # Draw detected lines
  if lines is not None:
    for line in lines:
      x1, y1, x2, y2 = line[0]
      cv2.line(img, (x1, y1), (x2, y2), (0,255, 0), 2)
  print("Image",i+1)
  cv2_imshow(img)
# Out:
# Image 1
# <PIL.Image.Image image mode=RGB size=360x250>
# Image 2
# <PIL.Image.Image image mode=RGB size=200x300>
# Image 3
# <PIL.Image.Image image mode=RGB size=642x481>
# Image 4
# <PIL.Image.Image image mode=RGB size=639x479>

# %% [markdown]
# **LAPLACIAN :-**

# %%
for i in range(4):
  # Read the original image
  img = cv2.imread(images[i])
  # Convert to graycsale
  img_gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
  # Blur the image for better edge detection
  img_blur = cv2.GaussianBlur(img_blur, (3,3), 0)
  dest = cv2.Laplacian(img_gray, cv2.CV_16S, ksize=3)
  abs_dest = cv2.convertScaleAbs(dest)
  print("Image",i+1)
  cv2_imshow(abs_dest)
# Out:
# Image 1
# <PIL.Image.Image image mode=L size=360x250>
# Image 2
# <PIL.Image.Image image mode=L size=200x300>
# Image 3
# <PIL.Image.Image image mode=L size=642x481>
# Image 4
# <PIL.Image.Image image mode=L size=639x479>

# %% [markdown]
# **EDGE DETECTION USING GRADIENTS - SOBEL, PREWITT, ROBERT OPERATORS :-**

# %%
# SOBEL OPERATOR :-

for i in range(4):
  # Read the original image
  img = cv2.imread(images[i])
  # Convert to graycsale
  img_gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
  # Blur the image for better edge detection
  img_blur = cv2.GaussianBlur(img_gray, (3,3), 0)
  # Combined X and Y Sobel Edge Detection
  sobelxy = cv2.Sobel(src=img_blur, ddepth=cv2.CV_64F, dx=1, dy=1, ksize=5)
  print("Image",i+1)
  cv2_imshow(sobelxy)
# Out:
# Image 1
# <PIL.Image.Image image mode=L size=360x250>
# Image 2
# <PIL.Image.Image image mode=L size=200x300>
# Image 3
# <PIL.Image.Image image mode=L size=642x481>
# Image 4
# <PIL.Image.Image image mode=L size=639x479>

# %%
# PREWITT OPERATOR :-

for i in range(4):
  # Read the original image
  img = cv2.imread(images[i])
  # Convert to graycsale
  img_gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
  # Blur the image for better edge detection
  img_blur = cv2.GaussianBlur(img_gray, (3,3), 0)
  kernelx = np.array([[1,1,1],[0,0,0],[-1,-1,-1]])
  kernely = np.array([[-1,0,1],[-1,0,1],[-1,0,1]])
  img_prewittx = cv2.filter2D(img_blur, -1, kernelx)
  img_prewitty = cv2.filter2D(img_blur, -1, kernely)
  img_prewittxy = img_prewittx + img_prewitty
  print("Image",i+1)
  cv2_imshow(img_prewittxy)
# Out:
# Image 1
# <PIL.Image.Image image mode=L size=360x250>
# Image 2
# <PIL.Image.Image image mode=L size=200x300>
# Image 3
# <PIL.Image.Image image mode=L size=642x481>
# Image 4
# <PIL.Image.Image image mode=L size=639x479>

# %%
# ROBERT OPERATOR :-

for i in range(4):
  # Read the original image
  img = cv2.imread(images[i])
  # Convert to graycsale
  img_gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
  # Blur the image for better edge detection
  img_blur = cv2.GaussianBlur(img_gray, (3,3), 0)
  kernelx = np.array([[1, 0], [0, -1]])
  kernely = np.array([[0, 1], [-1, 0]])
  img_robertx = cv2.filter2D(img_blur, -1, kernelx)
  img_roberty = cv2.filter2D(img_blur, -1, kernely)
  img_robertxy = img_robertx + img_roberty
  print("Image",i+1)
  cv2_imshow(img_robertxy)
# Out:
# Image 1
# <PIL.Image.Image image mode=L size=360x250>
# Image 2
# <PIL.Image.Image image mode=L size=200x300>
# Image 3
# <PIL.Image.Image image mode=L size=642x481>
# Image 4
# <PIL.Image.Image image mode=L size=639x479>

# %% [markdown]
# **INFERENCE :-**
# CANNY EDGE DETECTION GIVES THE BEST RESULTS.
