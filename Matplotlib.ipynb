# %% [markdown]
# <a href="https://colab.research.google.com/github/ak-mpbf/Vision-Verse/blob/main/Matplotlib.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ** Import matplotlib.pyplot as plt

# %%
import matplotlib.pyplot as plt
import numpy as np
x = np.arange(0,100)
y = x*2
z = x**2

# %% [markdown]
# ## Exercise 1
#
# ** Follow along with these steps: **
# * ** Create a figure object called fig using plt.figure() **
# * ** Use add_axes to add an axis to the figure canvas at [0,0,1,1]. Call this new axis ax. **
# * ** Plot (x,y) on that axes and set the labels and titles to match the plot below:**

# %%
fig = plt.figure()
ax = fig.add_axes([0, 0, 1, 1])
ax.set_xticks([-0.04,-0.02,0.00,0.02,0.04])
ax.set_xlim(-0.06,0.06)
ax.set_yticks([])
ax.set_ylim(-0.12,0.12)
ax.plot(x, y)
ax.set_xlabel('x')
ax.set_ylabel('y')
ax.set_title('title')
plt.show()

# %% [markdown]
# ## Exercise 2
# ** Create a figure object and put two axes on it, ax1 and ax2. Located at [0,0,1,1] and [0.2,0.5,.2,.2] respectively.**

# %% [markdown]
# ** Now plot (x,y) on both axes. And call your figure object to show it.**

# %%
fig1=plt.figure()
ax1=fig1.add_axes([0,0,1,1])
ax1.set_xlabel('x')
ax1.set_ylabel('y')
ax1.set_title('ax1')
ax1.plot(x,y)
ax2=fig1.add_axes([0.2,0.5,0.2,0.2])
ax2.set_xlabel('x')
ax2.set_ylabel('y')
ax2.set_title('ax2')
ax2.plot(x,y)
plt.show()

# %% [markdown]
# ## Exercise 3
#
# ** Create the plot below by adding two axes to a figure object at [0,0,1,1] and [0.2,0.5,.4,.4]**

# %%
fig2=plt.figure()
ax1=fig2.add_axes([0,0,1,1])
ax2=fig2.add_axes([0.2,0.5,0.4,0.4])
plt.show()

# %% [markdown]
# ## Exercise 4
#
# ** Use plt.subplots(nrows=1, ncols=2) to create the plot below.**

# %%
fig, axes = plt.subplots(nrows=1, ncols=2)
axes[0].plot(x,y,linestyle='--',color='blue')
axes[0].set_xticks([0, 20, 40, 60, 80, 100])
axes[0].set_yticks([0, 50, 100, 150, 200])
axes[0].set_xlim([0,100])
axes[0].set_ylim([0,200])
axes[1].plot(x,z,color='red')
axes[1].set_xticks([0,20,40,60,80,100])
axes[1].set_yticks([0,2000,4000,6000,8000,10000])
axes[1].set_xlim([0,100])
axes[1].set_ylim([0,10000])
plt.show()

# %% [markdown]
# ** Now plot (x,y) and (x,z) on the axes. Play around with the linewidth and style**

# %%
fig, axes = plt.subplots(nrows=1, ncols=2)
axes[0].plot(x,y,linestyle='-',color='blue',linewidth=3)
axes[0].set_xticks([0, 20, 40, 60, 80, 100])
axes[0].set_yticks([0, 50, 100, 150, 200])
axes[0].set_xlim([0,100])
axes[0].set_ylim([0,200])
axes[1].plot(x,z,color='red',linewidth=5,linestyle=':')
axes[1].set_xticks([0,20,40,60,80,100])
axes[1].set_yticks([0,2000,4000,6000,8000,10000])
axes[1].set_xlim([0,100])
axes[1].set_ylim([0,10000])
plt.show()

# %% [markdown]
# # Great Job!
